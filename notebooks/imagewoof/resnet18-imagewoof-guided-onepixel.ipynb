# %% [markdown]
# # Guided One Pixel Attack: ResNet18 на Imagewoof
#
# Сравнение обычного DE, surrogate Grad-CAM guidance и black-box occlusion guidance на FGSM-дообученной модели.

# %%
# !pip install lightning -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 2.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 848.6/848.6 kB 20.7 MB/s eta 0:00:0000:01

# %%
from dataclasses import asdict, dataclass
from pathlib import Path
from typing import Callable, Optional
import copy
import csv
import hashlib
import json
import tarfile

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from PIL import Image
import torch
import torch.nn as nn
import lightning as L
from torch.utils.data import DataLoader
from torchvision import datasets, models, transforms

SEED = 42
L.seed_everything(SEED, workers=True)
np.random.seed(SEED)

IMAGEWOOF_ARCHIVE = Path('/kaggle/input/datasets/renrgaming2000/imagewoof2-329/imagewoof2-320.tgz')
WEIGHTS_DIR = Path('/kaggle/input/datasets/notquartzz/weights-aa')
BASELINE_WEIGHTS = WEIGHTS_DIR / 'resnet18_imagewoof_best.pth'
ROBUST_WEIGHTS = WEIGHTS_DIR / 'resnet18_imagewoof_fgsm_robust (1).pth'
KAGGLE_INPUT = Path('/kaggle/input')
EXTRACT_DIR = Path('/tmp/imagewoof_onepixel')
OUTPUT_DIR = Path('/kaggle/working/imagewoof_guided_onepixel')
EXAMPLES_DIR = OUTPUT_DIR / 'examples'

IMAGE_SIZE = 224
BATCH_SIZE = 64
NUM_WORKERS = 2
# MAX_ATTACK_SAMPLES = 50
# POPULATION_SIZE = 100
# GENERATIONS = 40
MAX_ATTACK_SAMPLES = 30
POPULATION_SIZE = 80
GENERATIONS = 30
DIFFERENTIAL_WEIGHT = 0.5
TARGET_THRESHOLD = 0.90
ORIGINAL_THRESHOLD = 0.05
PREDICT_BATCH_SIZE = 32
EXAMPLES_PER_COMBINATION = 2
GUIDANCE_STRENGTH = 0.80
OCCLUSION_PATCH_SIZE = 16
GUIDANCE_EXAMPLES = 1
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
EXAMPLES_DIR.mkdir(parents=True, exist_ok=True)
print('Device:', DEVICE)
print('Maximum evaluations per attack:', 1 + POPULATION_SIZE * (GENERATIONS + 1))
# Out:
# Seed set to 42
# Device: cuda
# Maximum evaluations per attack: 2481

# %% [markdown]
# ## Датасет Imagewoof

# %%
def find_imagewoof_archive(configured_path: Path) -> Path:
    if configured_path.is_file():
        return configured_path
    candidates = sorted(
        path for path in KAGGLE_INPUT.rglob('*')
        if path.is_file() and 'imagewoof' in path.name.lower()
        and (path.name.endswith('.tgz') or path.name.endswith('.tar.gz'))
    )
    if len(candidates) != 1:
        raise FileNotFoundError(
            f'Ожидался один архив Imagewoof. Настроенный путь: {configured_path}. Найдено: {candidates}'
        )
    return candidates[0]


def resolve_dataset_root(search_root: Path) -> Path:
    if (search_root / 'train').is_dir() and (search_root / 'val').is_dir():
        return search_root
    candidates = sorted(
        path.parent for path in search_root.rglob('train')
        if path.is_dir() and (path.parent / 'val').is_dir()
    ) if search_root.exists() else []
    preferred = [path for path in candidates if 'imagewoof' in str(path).lower()]
    if len(preferred) == 1:
        return preferred[0]
    if len(candidates) == 1:
        return candidates[0]
    raise FileNotFoundError(f'Не найден единственный Imagewoof train/val в {search_root}: {candidates}')


def prepare_imagewoof() -> Path:
    try:
        root = resolve_dataset_root(EXTRACT_DIR)
        print('Используется уже распакованный датасет:', root)
        return root
    except FileNotFoundError:
        pass
    archive_path = find_imagewoof_archive(IMAGEWOOF_ARCHIVE)
    EXTRACT_DIR.mkdir(parents=True, exist_ok=True)
    print(f'Распаковка {archive_path} в {EXTRACT_DIR} ...')
    with tarfile.open(archive_path, 'r:*') as archive:
        archive.extractall(EXTRACT_DIR, filter='data')
    root = resolve_dataset_root(EXTRACT_DIR)
    print('Dataset root:', root)
    return root


class ImagewoofDataModule(L.LightningDataModule):
    def __init__(self, batch_size=BATCH_SIZE, num_workers=NUM_WORKERS):
        super().__init__()
        self.batch_size = batch_size
        self.num_workers = num_workers
        self.val_transform = transforms.Compose([
            transforms.Resize(256),
            transforms.CenterCrop(IMAGE_SIZE),
            transforms.ToTensor(),
        ])

    def prepare_data(self):
        self.data_root = prepare_imagewoof()

    def setup(self, stage=None):
        if not hasattr(self, 'data_root'):
            self.prepare_data()
        self.val_set = datasets.ImageFolder(self.data_root / 'val', transform=self.val_transform)
        if len(self.val_set.classes) != 10:
            raise ValueError(f'Ожидалось 10 классов, найдено {len(self.val_set.classes)}')

    def test_dataloader(self):
        return DataLoader(
            self.val_set, batch_size=self.batch_size, shuffle=False,
            num_workers=self.num_workers, pin_memory=torch.cuda.is_available(),
            persistent_workers=self.num_workers > 0, drop_last=False,
        )

    def val_dataloader(self):
        return self.test_dataloader()


dm = ImagewoofDataModule()
dm.prepare_data()
dm.setup('test')
DATASET_ROOT = dm.data_root
val_set = dm.val_set
val_loader = dm.val_dataloader()
sample_x, sample_y = next(iter(val_loader))
assert sample_x.shape[1:] == (3, IMAGE_SIZE, IMAGE_SIZE)
assert 0.0 <= sample_x.min().item() <= sample_x.max().item() <= 1.0
print(f'Validation images: {len(val_set):,}')
print('Classes:', val_set.class_to_idx)
# Out:
# Распаковка /kaggle/input/datasets/renrgaming2000/imagewoof2-329/imagewoof2-320.tgz в /tmp/imagewoof_onepixel ...
# Dataset root: /tmp/imagewoof_onepixel/imagewoof2-320
# Validation images: 3,929
# Classes: {'n02086240': 0, 'n02087394': 1, 'n02088364': 2, 'n02089973': 3, 'n02093754': 4, 'n02096294': 5, 'n02099601': 6, 'n02105641': 7, 'n02111889': 8, 'n02115641': 9}

# %% [markdown]
# ## Модели и строгая загрузка весов

# %%
class Normalize(nn.Module):
    def __init__(self, mean, std):
        super().__init__()
        self.register_buffer('mean', torch.tensor(mean).view(1, -1, 1, 1))
        self.register_buffer('std', torch.tensor(std).view(1, -1, 1, 1))

    def forward(self, x):
        return (x - self.mean) / self.std


class NormalizedModel(nn.Module):
    def __init__(self, num_classes=10):
        super().__init__()
        self.normalize = Normalize(
            mean=(0.485, 0.456, 0.406),
            std=(0.229, 0.224, 0.225),
        )
        self.model = models.resnet18(weights=None, num_classes=num_classes)

    def forward(self, x):
        return self.model(self.normalize(x))


class ImagewoofClassifier(L.LightningModule):
    def __init__(self, num_classes=10):
        super().__init__()
        self.save_hyperparameters()
        self.model = NormalizedModel(num_classes=num_classes)

    def forward(self, x):
        return self.model(x)

    def test_step(self, batch, batch_idx):
        images, labels = batch
        logits = self(images)
        accuracy = (logits.argmax(1) == labels).float().mean()
        self.log('test_acc', accuracy, on_epoch=True, batch_size=labels.size(0))


def validate_weights_paths():
    missing = [path for path in (BASELINE_WEIGHTS, ROBUST_WEIGHTS) if not path.is_file()]
    if missing:
        available = sorted(path for path in WEIGHTS_DIR.rglob('*') if path.is_file()) if WEIGHTS_DIR.exists() else []
        raise FileNotFoundError(f'Не найдены веса: {missing}. Файлы в {WEIGHTS_DIR}: {available}')


def read_checkpoint(path: Path):
    if not path.is_file():
        raise FileNotFoundError(f'Не найдены веса: {path}')
    try:
        checkpoint = torch.load(path, map_location='cpu', weights_only=True)
    except TypeError:
        checkpoint = torch.load(path, map_location='cpu')
    if not isinstance(checkpoint, dict):
        raise TypeError(f'Checkpoint должен быть словарём, получено: {type(checkpoint)}')
    state = checkpoint.get('state_dict', checkpoint.get('model_state_dict', checkpoint))
    if not isinstance(state, dict):
        raise TypeError('В checkpoint не найден state_dict')
    return checkpoint, {key.removeprefix('module.'): value for key, value in state.items()}


def load_weights_strict(model: NormalizedModel, path: Path):
    checkpoint, state = read_checkpoint(path)
    if 'model.normalize.mean' in state:
        state = {key.removeprefix('model.'): value for key, value in state.items()}
    if 'normalize.mean' in state and any(key.startswith('model.') for key in state):
        model.load_state_dict(state, strict=True)
        loaded_into = 'normalized_model'
    else:
        raw_state = {}
        for key, value in state.items():
            if key in {'normalize.mean', 'normalize.std'}:
                continue
            key = key.removeprefix('backbone.').removeprefix('model.model.')
            raw_state[key] = value
        model.model.load_state_dict(raw_state, strict=True)
        loaded_into = 'resnet18'
    metadata = {key: checkpoint[key] for key in ('epoch', 'val_acc', 'validation_accuracy') if key in checkpoint}
    print(f'Loaded strictly into {loaded_into}: {path}')
    if metadata:
        print('Checkpoint metadata:', metadata)
    return metadata


def model_fingerprint(model: nn.Module) -> str:
    digest = hashlib.sha256()
    for key, value in sorted(model.state_dict().items()):
        digest.update(key.encode('utf-8'))
        digest.update(value.detach().cpu().contiguous().numpy().tobytes())
    return digest.hexdigest()


validate_weights_paths()
baseline_module = ImagewoofClassifier()
robust_module = ImagewoofClassifier()
load_weights_strict(baseline_module.model, BASELINE_WEIGHTS)
load_weights_strict(robust_module.model, ROBUST_WEIGHTS)
baseline_module = baseline_module.to(DEVICE).eval().requires_grad_(False)
robust_module = robust_module.to(DEVICE).eval().requires_grad_(False)
models_by_name = {'before': baseline_module, 'after': robust_module}
fingerprints_before = {name: model_fingerprint(net) for name, net in models_by_name.items()}
with torch.inference_mode():
    for name, net in models_by_name.items():
        logits = net(sample_x[:2].to(DEVICE))
        assert logits.shape == (2, 10), (name, logits.shape)
print('Model output checks passed')
# Out:
# Loaded strictly into resnet18: /kaggle/input/datasets/notquartzz/weights-aa/resnet18_imagewoof_best.pth
# Checkpoint metadata: {'epoch': 39, 'val_acc': 0.80580300330873}
# Loaded strictly into normalized_model: /kaggle/input/datasets/notquartzz/weights-aa/resnet18_imagewoof_fgsm_robust (1).pth
# Model output checks passed

# %% [markdown]
# ## Lightning smoke-тест

# %%
for model_name, lightning_model in models_by_name.items():
    smoke_trainer = L.Trainer(
        fast_dev_run=True, accelerator='auto', devices=1, logger=False,
        enable_checkpointing=False, enable_model_summary=False,
    )
    smoke_trainer.test(lightning_model, datamodule=dm, verbose=False)
    lightning_model.to(DEVICE).eval().requires_grad_(False)
    print(f'Lightning smoke-test passed: {model_name}')
del smoke_trainer
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# Running in `fast_dev_run` mode: will run the requested loop using 1 batch(es). Logging and checkpointing is suppressed.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# Используется уже распакованный датасет: /tmp/imagewoof_onepixel/imagewoof2-320
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/utilities/_pytree.py:21: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# Running in `fast_dev_run` mode: will run the requested loop using 1 batch(es). Logging and checkpointing is suppressed.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# Lightning smoke-test passed: before
# Используется уже распакованный датасет: /tmp/imagewoof_onepixel/imagewoof2-320
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Lightning smoke-test passed: after

# %% [markdown]
# ## One Pixel Attack: Differential Evolution без crossover

# %%
PredictFn = Callable[[np.ndarray], np.ndarray]


def make_predict_probs(model: nn.Module, batch_size=PREDICT_BATCH_SIZE) -> PredictFn:
    @torch.inference_mode()
    def predict_probs(batch_uint8: np.ndarray) -> np.ndarray:
        if batch_uint8.dtype != np.uint8 or batch_uint8.ndim != 4 or batch_uint8.shape[-1] != 3:
            raise ValueError(f'Ожидается NHWC uint8 RGB, получено {batch_uint8.shape} {batch_uint8.dtype}')
        outputs = []
        for start in range(0, len(batch_uint8), batch_size):
            chunk = np.ascontiguousarray(batch_uint8[start:start + batch_size])
            x = torch.from_numpy(chunk).to(DEVICE, dtype=torch.float32)
            x = x.permute(0, 3, 1, 2) / 255.0
            outputs.append(torch.softmax(model(x), dim=1).cpu().numpy())
        return np.concatenate(outputs, axis=0)
    return predict_probs


predictors = {name: make_predict_probs(net) for name, net in models_by_name.items()}


@dataclass
class AttackResult:
    success: bool
    image: np.ndarray
    vector: np.ndarray
    original_class: int
    predicted_class: int
    probabilities: np.ndarray
    generations: int
    evaluations: int


def apply_population(image: np.ndarray, population: np.ndarray) -> np.ndarray:
    if image.dtype != np.uint8 or image.ndim != 3 or image.shape[2] != 3:
        raise ValueError('Ожидается RGB-изображение HxWx3 с dtype=uint8')
    height, width, _ = image.shape
    candidates = np.repeat(image[None, ...], len(population), axis=0)
    vectors = np.rint(population).astype(np.int32)
    xs = np.clip(vectors[:, 0], 0, width - 1)
    ys = np.clip(vectors[:, 1], 0, height - 1)
    rgb = np.clip(vectors[:, 2:5], 0, 255).astype(np.uint8)
    candidates[np.arange(len(population)), ys, xs] = rgb
    return candidates


def one_pixel_attack(
    image: np.ndarray,
    predict_probs: PredictFn,
    target_class: Optional[int] = None,
    population_size: int = POPULATION_SIZE,
    generations: int = GENERATIONS,
    differential_weight: float = DIFFERENTIAL_WEIGHT,
    target_threshold: float = TARGET_THRESHOLD,
    original_threshold: float = ORIGINAL_THRESHOLD,
    coordinate_weights: Optional[np.ndarray] = None,
    seed: int = SEED,
) -> AttackResult:
    if population_size < 4 or generations < 1:
        raise ValueError('Требуются population_size >= 4 и generations >= 1')
    init_rng = np.random.default_rng(seed)
    evolution_rng = np.random.default_rng(seed + 1_000_003)
    height, width, _ = image.shape
    original_probs = predict_probs(image[None, ...])[0]
    original_class = int(original_probs.argmax())
    if target_class is not None and target_class == original_class:
        raise ValueError('Целевой класс должен отличаться от исходного')

    population = np.empty((population_size, 5), dtype=np.float64)
    if coordinate_weights is None:
        population[:, 0] = init_rng.uniform(0, width - 1, population_size)
        population[:, 1] = init_rng.uniform(0, height - 1, population_size)
    else:
        weights = np.asarray(coordinate_weights, dtype=np.float64)
        if weights.shape != (height, width) or not np.isfinite(weights).all() or (weights < 0).any():
            raise ValueError(f'Некорректная карта координат: {weights.shape}')
        if weights.sum() <= 0:
            raise ValueError('Сумма весов координат должна быть положительной')
        flat_indices = init_rng.choice(height * width, size=population_size, p=(weights / weights.sum()).ravel())
        population[:, 0] = flat_indices % width
        population[:, 1] = flat_indices // width
    population[:, 2:5] = np.clip(init_rng.normal(128, 127, (population_size, 3)), 0, 255)
    lower = np.array([0, 0, 0, 0, 0], dtype=np.float64)
    upper = np.array([width - 1, height - 1, 255, 255, 255], dtype=np.float64)
    evaluations = 1

    def evaluate(candidate_population):
        nonlocal evaluations
        probabilities = predict_probs(apply_population(image, candidate_population))
        evaluations += len(candidate_population)
        fitness = (
            -probabilities[:, original_class]
            if target_class is None else probabilities[:, target_class]
        )
        return fitness, probabilities

    def threshold_reached(probabilities):
        if target_class is None:
            return probabilities[original_class] < original_threshold
        return probabilities[target_class] > target_threshold

    fitness, probabilities = evaluate(population)
    generation = 0
    best_idx = int(fitness.argmax())
    while generation < generations and not threshold_reached(probabilities[best_idx]):
        generation += 1
        children = np.empty_like(population)
        all_indices = np.arange(population_size)
        for index in range(population_size):
            pool = np.delete(all_indices, index)
            r1, r2, r3 = evolution_rng.choice(pool, size=3, replace=False)
            children[index] = population[r1] + differential_weight * (population[r2] - population[r3])
        children = np.clip(children, lower, upper)
        child_fitness, child_probabilities = evaluate(children)
        improved = child_fitness > fitness
        population[improved] = children[improved]
        fitness[improved] = child_fitness[improved]
        probabilities[improved] = child_probabilities[improved]
        best_idx = int(fitness.argmax())

    best_vector = population[best_idx]
    adversarial = apply_population(image, best_vector[None, :])[0]
    final_probs = probabilities[best_idx]
    predicted_class = int(final_probs.argmax())
    success = (
        predicted_class != original_class
        if target_class is None else predicted_class == target_class
    )
    return AttackResult(
        success=success, image=adversarial, vector=np.rint(best_vector).astype(np.int32),
        original_class=original_class, predicted_class=predicted_class,
        probabilities=final_probs, generations=generation, evaluations=evaluations,
    )

# %% [markdown]
# ## Общая clean-correct выборка и smoke-тест

# %%
selected_images = []
selected_labels = []
selected_dataset_indices = []
dataset_offset = 0
for images, labels in val_loader:
    batch_uint8 = (images.mul(255).round().clamp(0, 255).byte().permute(0, 2, 3, 1).numpy())
    predictions = {name: predictor(batch_uint8).argmax(1) for name, predictor in predictors.items()}
    common_correct = np.ones(len(labels), dtype=bool)
    for prediction in predictions.values():
        common_correct &= prediction == labels.numpy()
    for local_index in np.flatnonzero(common_correct):
        selected_images.append(batch_uint8[local_index].copy())
        selected_labels.append(int(labels[local_index]))
        selected_dataset_indices.append(dataset_offset + int(local_index))
        if len(selected_images) >= MAX_ATTACK_SAMPLES:
            break
    dataset_offset += len(labels)
    if len(selected_images) >= MAX_ATTACK_SAMPLES:
        break

if len(selected_images) < MAX_ATTACK_SAMPLES:
    raise RuntimeError(f'Найдено только {len(selected_images)} общих clean-correct изображений')
selected_images = np.stack(selected_images)
selected_labels = np.asarray(selected_labels, dtype=np.int64)
target_rng = np.random.default_rng(SEED)
target_base = target_rng.integers(0, 9, size=len(selected_labels))
target_classes = target_base + (target_base >= selected_labels)
assert np.all(target_classes != selected_labels)
assert selected_images.dtype == np.uint8 and selected_images.shape[1:] == (IMAGE_SIZE, IMAGE_SIZE, 3)
print('Common clean-correct samples:', len(selected_images))

smoke = one_pixel_attack(
    selected_images[0], predictors['before'], target_class=None,
    population_size=8, generations=2, seed=SEED,
)
changed = np.any(smoke.image != selected_images[0], axis=2)
assert smoke.image.dtype == np.uint8 and smoke.image.shape == selected_images[0].shape
assert int(changed.sum()) <= 1
assert smoke.success == (smoke.predicted_class != smoke.original_class)
print('Smoke-test passed:', {'success': smoke.success, 'evaluations': smoke.evaluations})
# Out:
# Common clean-correct samples: 30
# Smoke-test passed: {'success': False, 'evaluations': 25}

# %% [markdown]
# ## Карты выбора координат

# %%
def normalize_guidance(raw_map: np.ndarray, strength=GUIDANCE_STRENGTH) -> np.ndarray:
    values = np.nan_to_num(np.asarray(raw_map, dtype=np.float64), nan=0.0, posinf=0.0, neginf=0.0)
    values = np.maximum(values, 0.0)
    uniform = np.full(values.shape, 1.0 / values.size, dtype=np.float64)
    if values.sum() <= 0:
        return uniform
    guided = values / values.sum()
    mixed = strength * guided + (1.0 - strength) * uniform
    return mixed / mixed.sum()


def surrogate_gradcam_guidance(
    surrogate: ImagewoofClassifier,
    image_uint8: np.ndarray,
    source_class: int,
    target_class: Optional[int],
):
    surrogate.eval()
    image_tensor = torch.from_numpy(np.ascontiguousarray(image_uint8)).to(DEVICE, dtype=torch.float32)
    image_tensor = (image_tensor.permute(2, 0, 1).unsqueeze(0) / 255.0).requires_grad_(True)
    captured = {}

    def capture_activation(module, inputs, output):
        captured['activation'] = output

    handle = surrogate.model.model.layer4[-1].register_forward_hook(capture_activation)
    try:
        logits = surrogate(image_tensor)
        activation = captured['activation']
        classes = [source_class] if target_class is None else [source_class, target_class]
        cams = []
        for class_index in classes:
            gradient = torch.autograd.grad(logits[0, class_index], activation, retain_graph=True)[0]
            channel_weights = gradient.mean(dim=(2, 3), keepdim=True)
            cam = torch.relu((channel_weights * activation).sum(dim=1, keepdim=True))
            cam = torch.nn.functional.interpolate(
                cam, size=image_uint8.shape[:2], mode='bilinear', align_corners=False,
            )[0, 0]
            cam = cam - cam.min()
            if cam.max() > 0:
                cam = cam / cam.max()
            cams.append(cam.detach().cpu().numpy())
    finally:
        handle.remove()
    combined = np.mean(cams, axis=0)
    return normalize_guidance(combined), len(classes)


def occlusion_guidance(
    image_uint8: np.ndarray,
    predict_probs: PredictFn,
    source_class: int,
    target_class: Optional[int],
    patch_size=OCCLUSION_PATCH_SIZE,
):
    height, width, _ = image_uint8.shape
    baseline_probs = predict_probs(image_uint8[None, ...])[0]
    locations = []
    candidates = []
    fill_rgb = np.rint(image_uint8.mean(axis=(0, 1))).astype(np.uint8)
    for top in range(0, height, patch_size):
        for left in range(0, width, patch_size):
            bottom, right = min(top + patch_size, height), min(left + patch_size, width)
            candidate = image_uint8.copy()
            candidate[top:bottom, left:right] = fill_rgb
            candidates.append(candidate)
            locations.append((top, bottom, left, right))
    candidate_probs = predict_probs(np.stack(candidates))
    source_drop = baseline_probs[source_class] - candidate_probs[:, source_class]
    if target_class is None:
        scores = source_drop
    else:
        target_gain = candidate_probs[:, target_class] - baseline_probs[target_class]
        scores = source_drop + target_gain
    scores = np.maximum(scores, 0.0)
    heatmap = np.zeros((height, width), dtype=np.float64)
    for score, (top, bottom, left, right) in zip(scores, locations):
        heatmap[top:bottom, left:right] = score
    target_queries = 1 + len(candidates)
    return normalize_guidance(heatmap), target_queries


SURROGATE_FOR_TARGET = {'before': 'after', 'after': 'before'}


def make_guidance(method, image, source_class, target_class, target_model_name):
    if method == 'uniform':
        return None, 0, 0
    if method == 'surrogate_gradcam':
        surrogate_name = SURROGATE_FOR_TARGET[target_model_name]
        weights, surrogate_passes = surrogate_gradcam_guidance(
            models_by_name[surrogate_name], image, source_class, target_class,
        )
        return weights, 0, surrogate_passes
    if method == 'occlusion':
        weights, target_queries = occlusion_guidance(
            image, predictors[target_model_name], source_class, target_class,
        )
        return weights, target_queries, 0
    raise ValueError(f'Неизвестный метод guidance: {method}')

# %% [markdown]
# ## Smoke-тест guidance

# %%
for smoke_target_name in ('before', 'after'):
    for smoke_method in ('surrogate_gradcam', 'occlusion'):
        smoke_map, smoke_queries, smoke_surrogate_passes = make_guidance(
            smoke_method, selected_images[0], int(selected_labels[0]), None, smoke_target_name,
        )
        assert smoke_map.shape == (IMAGE_SIZE, IMAGE_SIZE)
        assert np.isfinite(smoke_map).all() and (smoke_map >= 0).all()
        assert np.isclose(smoke_map.sum(), 1.0)
        smoke_result = one_pixel_attack(
            selected_images[0], predictors[smoke_target_name], target_class=None,
            population_size=8, generations=2, coordinate_weights=smoke_map, seed=SEED,
        )
        changed = np.any(smoke_result.image != selected_images[0], axis=2)
        assert int(changed.sum()) <= 1
        print(smoke_target_name, smoke_method, {
            'guidance_queries': smoke_queries, 'surrogate_passes': smoke_surrogate_passes,
        })
print('Guidance smoke-tests passed')
# Out:
# before surrogate_gradcam {'guidance_queries': 0, 'surrogate_passes': 1}
# before occlusion {'guidance_queries': 197, 'surrogate_passes': 0}
# after surrogate_gradcam {'guidance_queries': 0, 'surrogate_passes': 1}
# after occlusion {'guidance_queries': 197, 'surrogate_passes': 0}
# Guidance smoke-tests passed

# %% [markdown]
# ## Сравнение uniform, surrogate Grad-CAM и occlusion guidance

# %%
METHODS = ('uniform', 'surrogate_gradcam', 'occlusion')
MODES = ('untargeted', 'targeted')
TARGET_MODEL_NAMES = ('before', 'after')
GUIDED_RESULTS_PATH = OUTPUT_DIR / 'guided_onepixel_results.csv'

guided_records = []
visual_examples = []
for target_model_name in TARGET_MODEL_NAMES:
    for mode_index, mode in enumerate(MODES):
        for sample_index, (image, true_class, chosen_target) in enumerate(
            zip(selected_images, selected_labels, target_classes)
        ):
            attack_target = None if mode == 'untargeted' else int(chosen_target)
            attack_seed = SEED + sample_index * 10 + mode_index
            for method in METHODS:
                coordinate_weights, guidance_target_queries, surrogate_passes = make_guidance(
                    method, image, int(true_class), attack_target, target_model_name,
                )
                result = one_pixel_attack(
                    image=image,
                    predict_probs=predictors[target_model_name],
                    target_class=attack_target,
                    population_size=POPULATION_SIZE,
                    generations=GENERATIONS,
                    differential_weight=DIFFERENTIAL_WEIGHT,
                    coordinate_weights=coordinate_weights,
                    seed=attack_seed,
                )
                changed_positions = np.argwhere(np.any(result.image != image, axis=2))
                assert len(changed_positions) <= 1
                expected_success = (
                    result.predicted_class != result.original_class
                    if attack_target is None else result.predicted_class == attack_target
                )
                assert result.success == expected_success
                record = {
                    'method': method,
                    'mode': mode,
                    'target_model': target_model_name,
                    'surrogate_model': (
                        SURROGATE_FOR_TARGET[target_model_name] if method == 'surrogate_gradcam' else None
                    ),
                    'sample_index': sample_index,
                    'dataset_index': selected_dataset_indices[sample_index],
                    'true_class': int(true_class),
                    'target_class': attack_target,
                    'clean_prediction': result.original_class,
                    'adversarial_prediction': result.predicted_class,
                    'success': bool(result.success),
                    'post_attack_correct': result.predicted_class == int(true_class),
                    'de_evaluations': result.evaluations,
                    'guidance_target_queries': guidance_target_queries,
                    'surrogate_backward_passes': surrogate_passes,
                    'total_target_queries': result.evaluations + guidance_target_queries,
                    'generations': result.generations,
                    'x': int(result.vector[0]),
                    'y': int(result.vector[1]),
                    'new_rgb': result.vector[2:5].tolist(),
                    'changed_pixels': int(len(changed_positions)),
                }
                guided_records.append(record)
                pd.DataFrame(guided_records).to_csv(GUIDED_RESULTS_PATH, index=False)
                if method != 'uniform' and sample_index < GUIDANCE_EXAMPLES:
                    visual_examples.append({
                        **record,
                        'original': image.copy(),
                        'adversarial': result.image.copy(),
                        'guidance': coordinate_weights.copy(),
                    })
                print(
                    f'{target_model_name:>6} | {method:>18} | {mode:>10} | '
                    f'{sample_index + 1:02d}/{len(selected_images)} | success={result.success} | '
                    f'target_queries={record["total_target_queries"]}'
                )

guided_results_df = pd.DataFrame(guided_records)
display(guided_results_df.head())
# Out:
# before |            uniform | untargeted | 01/30 | success=False | target_queries=2481
# before |  surrogate_gradcam | untargeted | 01/30 | success=False | target_queries=2481
# before |          occlusion | untargeted | 01/30 | success=False | target_queries=2678
# before |            uniform | untargeted | 02/30 | success=False | target_queries=2481
# before |  surrogate_gradcam | untargeted | 02/30 | success=False | target_queries=2481
# before |          occlusion | untargeted | 02/30 | success=False | target_queries=2678
# before |            uniform | untargeted | 03/30 | success=False | target_queries=2481
# before |  surrogate_gradcam | untargeted | 03/30 | success=False | target_queries=2481
# before |          occlusion | untargeted | 03/30 | success=False | target_queries=2678
# before |            uniform | untargeted | 04/30 | success=False | target_queries=2481
# before |  surrogate_gradcam | untargeted | 04/30 | success=False | target_queries=2481
# before |          occlusion | untargeted | 04/30 | success=False | target_queries=2678
# before |            uniform | untargeted | 05/30 | success=False | target_queries=2481
# before |  surrogate_gradcam | untargeted | 05/30 | success=False | target_queries=2481
# before |          occlusion | untargeted | 05/30 | success=False | target_queries=2678
# before |            uniform | untargeted | 06/30 | success=False | target_queries=2481
# before |  surrogate_gradcam | untargeted | 06/30 | success=False | target_queries=2481
# before |          occlusion | untargeted | 06/30 | success=False | target_queries=2678
# before |            uniform | untargeted | 07/30 | success=False | target_queries=2481
# before |  surrogate_gradcam | untargeted | 07/30 | success=False | target_queries=2481
# before |          occlusion | untargeted | 07/30 | success=False | target_queries=2678
# before |            uniform | untargeted | 08/30 | success=False | target_queries=2481
# before |  surrogate_gradcam | untargeted | 08/30 | success=False | target_queries=2481
# before |          occlusion | untargeted | 08/30 | success=False | target_queries=2678
# before |            uniform | untargeted | 09/30 | success=False | target_queries=2481
# before |  surrogate_gradcam | untargeted | 09/30 | success=False | target_queries=2481
# before |          occlusion | untargeted | 09/30 | success=False | target_queries=2678
# before |            uniform | untargeted | 10/30 | success=False | target_queries=2481
# before |  surrogate_gradcam | untargeted | 10/30 | success=False | target_queries=2481
# before |          occlusion | untargeted | 10/30 | success=False | target_queries=2678
# before |            uniform | untargeted | 11/30 | success=False | target_queries=2481
# before |  surrogate_gradcam | untargeted | 11/30 | success=False | target_queries=2481
# before |          occlusion | untargeted | 11/30 | success=False | target_queries=2678
# before |            uniform | untargeted | 12/30 | success=False | target_queries=2481
# before |  surrogate_gradcam | untargeted | 12/30 | success=False | target_queries=2481
# before |          occlusion | untargeted | 12/30 | success=False | target_queries=2678
# before |            uniform | untargeted | 13/30 | success=False | target_queries=2481
# before |  surrogate_gradcam | untargeted | 13/30 | success=False | target_queries=2481
# before |          occlusion | untargeted | 13/30 | success=False | target_queries=2678
# before |            uniform | untargeted | 14/30 | success=False | target_queries=2481
# before |  surrogate_gradcam | untargeted | 14/30 | success=False | target_queries=2481
# before |          occlusion | untargeted | 14/30 | success=False | target_queries=2678
# before |            uniform | untargeted | 15/30 | success=False | target_queries=2481
# before |  surrogate_gradcam | untargeted | 15/30 | success=False | target_queries=2481
# before |          occlusion | untargeted | 15/30 | success=False | target_queries=2678
# before |            uniform | untargeted | 16/30 | success=False | target_queries=2481
# before |  surrogate_gradcam | untargeted | 16/30 | success=False | target_queries=2481
# before |          occlusion | untargeted | 16/30 | success=False | target_queries=2678
# before |            uniform | untargeted | 17/30 | success=False | target_queries=2481
# before |  surrogate_gradcam | untargeted | 17/30 | success=False | target_queries=2481
# before |          occlusion | untargeted | 17/30 | success=False | target_queries=2678
# before |            uniform | untargeted | 18/30 | success=True | target_queries=2481
# before |  surrogate_gradcam | untargeted | 18/30 | success=True | target_queries=2481
# before |          occlusion | untargeted | 18/30 | success=True | target_queries=2678
# before |            uniform | untargeted | 19/30 | success=False | target_queries=2481
# before |  surrogate_gradcam | untargeted | 19/30 | success=False | target_queries=2481
# before |          occlusion | untargeted | 19/30 | success=False | target_queries=2678
# before |            uniform | untargeted | 20/30 | success=False | target_queries=2481
# before |  surrogate_gradcam | untargeted | 20/30 | success=False | target_queries=2481
# before |          occlusion | untargeted | 20/30 | success=False | target_queries=2678
# before |            uniform | untargeted | 21/30 | success=True | target_queries=2481
# before |  surrogate_gradcam | untargeted | 21/30 | success=True | target_queries=2481
# before |          occlusion | untargeted | 21/30 | success=True | target_queries=2678
# before |            uniform | untargeted | 22/30 | success=False | target_queries=2481
# before |  surrogate_gradcam | untargeted | 22/30 | success=False | target_queries=2481
# before |          occlusion | untargeted | 22/30 | success=False | target_queries=2678
# before |            uniform | untargeted | 23/30 | success=False | target_queries=2481
# before |  surrogate_gradcam | untargeted | 23/30 | success=False | target_queries=2481
# before |          occlusion | untargeted | 23/30 | success=False | target_queries=2678
# before |            uniform | untargeted | 24/30 | success=False | target_queries=2481
# before |  surrogate_gradcam | untargeted | 24/30 | success=False | target_queries=2481
# before |          occlusion | untargeted | 24/30 | success=False | target_queries=2678
# before |            uniform | untargeted | 25/30 | success=False | target_queries=2481
# before |  surrogate_gradcam | untargeted | 25/30 | success=False | target_queries=2481
# before |          occlusion | untargeted | 25/30 | success=False | target_queries=2678
# before |            uniform | untargeted | 26/30 | success=False | target_queries=2481
# before |  surrogate_gradcam | untargeted | 26/30 | success=False | target_queries=2481
# before |          occlusion | untargeted | 26/30 | success=False | target_queries=2678
# before |            uniform | untargeted | 27/30 | success=False | target_queries=2481
# before |  surrogate_gradcam | untargeted | 27/30 | success=False | target_queries=2481
# before |          occlusion | untargeted | 27/30 | success=False | target_queries=2678
# before |            uniform | untargeted | 28/30 | success=False | target_queries=2481
# before |  surrogate_gradcam | untargeted | 28/30 | success=False | target_queries=2481
# before |          occlusion | untargeted | 28/30 | success=False | target_queries=2678
# before |            uniform | untargeted | 29/30 | success=False | target_queries=2481
# before |  surrogate_gradcam | untargeted | 29/30 | success=False | target_queries=2481
# before |          occlusion | untargeted | 29/30 | success=False | target_queries=2678
# before |            uniform | untargeted | 30/30 | success=False | target_queries=2481
# before |  surrogate_gradcam | untargeted | 30/30 | success=False | target_queries=2481
# before |          occlusion | untargeted | 30/30 | success=False | target_queries=2678
# before |            uniform |   targeted | 01/30 | success=False | target_queries=2481
# before |  surrogate_gradcam |   targeted | 01/30 | success=False | target_queries=2481
# before |          occlusion |   targeted | 01/30 | success=False | target_queries=2678
# before |            uniform |   targeted | 02/30 | success=False | target_queries=2481
# before |  surrogate_gradcam |   targeted | 02/30 | success=False | target_queries=2481
# before |          occlusion |   targeted | 02/30 | success=True | target_queries=2678
# before |            uniform |   targeted | 03/30 | success=False | target_queries=2481
# before |  surrogate_gradcam |   targeted | 03/30 | success=False | target_queries=2481
# before |          occlusion |   targeted | 03/30 | success=False | target_queries=2678
# before |            uniform |   targeted | 04/30 | success=False | target_queries=2481
# before |  surrogate_gradcam |   targeted | 04/30 | success=False | target_queries=2481
# before |          occlusion |   targeted | 04/30 | success=False | target_queries=2678
# before |            uniform |   targeted | 05/30 | success=False | target_queries=2481
# before |  surrogate_gradcam |   targeted | 05/30 | success=False | target_queries=2481
# before |          occlusion |   targeted | 05/30 | success=False | target_queries=2678
# before |            uniform |   targeted | 06/30 | success=False | target_queries=2481
# before |  surrogate_gradcam |   targeted | 06/30 | success=False | target_queries=2481
# before |          occlusion |   targeted | 06/30 | success=False | target_queries=2678
# before |            uniform |   targeted | 07/30 | success=False | target_queries=2481
# before |  surrogate_gradcam |   targeted | 07/30 | success=False | target_queries=2481
# before |          occlusion |   targeted | 07/30 | success=False | target_queries=2678
# before |            uniform |   targeted | 08/30 | success=False | target_queries=2481
# before |  surrogate_gradcam |   targeted | 08/30 | success=False | target_queries=2481
# before |          occlusion |   targeted | 08/30 | success=False | target_queries=2678
# before |            uniform |   targeted | 09/30 | success=False | target_queries=2481
# before |  surrogate_gradcam |   targeted | 09/30 | success=False | target_queries=2481
# before |          occlusion |   targeted | 09/30 | success=False | target_queries=2678
# before |            uniform |   targeted | 10/30 | success=False | target_queries=2481
# before |  surrogate_gradcam |   targeted | 10/30 | success=False | target_queries=2481
# before |          occlusion |   targeted | 10/30 | success=False | target_queries=2678
# before |            uniform |   targeted | 11/30 | success=False | target_queries=2481
# before |  surrogate_gradcam |   targeted | 11/30 | success=False | target_queries=2481
# before |          occlusion |   targeted | 11/30 | success=False | target_queries=2678
# before |            uniform |   targeted | 12/30 | success=False | target_queries=2481
# before |  surrogate_gradcam |   targeted | 12/30 | success=False | target_queries=2481
# before |          occlusion |   targeted | 12/30 | success=False | target_queries=2678
# before |            uniform |   targeted | 13/30 | success=False | target_queries=2481
# before |  surrogate_gradcam |   targeted | 13/30 | success=False | target_queries=2481
# before |          occlusion |   targeted | 13/30 | success=False | target_queries=2678
# before |            uniform |   targeted | 14/30 | success=False | target_queries=2481
# before |  surrogate_gradcam |   targeted | 14/30 | success=False | target_queries=2481
# before |          occlusion |   targeted | 14/30 | success=False | target_queries=2678
# before |            uniform |   targeted | 15/30 | success=False | target_queries=2481
# before |  surrogate_gradcam |   targeted | 15/30 | success=False | target_queries=2481
# before |          occlusion |   targeted | 15/30 | success=False | target_queries=2678
# before |            uniform |   targeted | 16/30 | success=False | target_queries=2481
# before |  surrogate_gradcam |   targeted | 16/30 | success=False | target_queries=2481
# before |          occlusion |   targeted | 16/30 | success=False | target_queries=2678
# before |            uniform |   targeted | 17/30 | success=False | target_queries=2481
# before |  surrogate_gradcam |   targeted | 17/30 | success=False | target_queries=2481
# before |          occlusion |   targeted | 17/30 | success=False | target_queries=2678
# before |            uniform |   targeted | 18/30 | success=False | target_queries=2481
# before |  surrogate_gradcam |   targeted | 18/30 | success=False | target_queries=2481
# before |          occlusion |   targeted | 18/30 | success=False | target_queries=2678
# before |            uniform |   targeted | 19/30 | success=False | target_queries=2481
# before |  surrogate_gradcam |   targeted | 19/30 | success=False | target_queries=2481
# before |          occlusion |   targeted | 19/30 | success=False | target_queries=2678
# before |            uniform |   targeted | 20/30 | success=False | target_queries=2481
# before |  surrogate_gradcam |   targeted | 20/30 | success=False | target_queries=2481
# before |          occlusion |   targeted | 20/30 | success=False | target_queries=2678
# before |            uniform |   targeted | 21/30 | success=False | target_queries=2481
# before |  surrogate_gradcam |   targeted | 21/30 | success=False | target_queries=2481
# before |          occlusion |   targeted | 21/30 | success=False | target_queries=2678
# before |            uniform |   targeted | 22/30 | success=False | target_queries=2481
# before |  surrogate_gradcam |   targeted | 22/30 | success=False | target_queries=2481
# before |          occlusion |   targeted | 22/30 | success=False | target_queries=2678
# before |            uniform |   targeted | 23/30 | success=False | target_queries=2481
# before |  surrogate_gradcam |   targeted | 23/30 | success=False | target_queries=2481
# before |          occlusion |   targeted | 23/30 | success=False | target_queries=2678
# before |            uniform |   targeted | 24/30 | success=False | target_queries=2481
# before |  surrogate_gradcam |   targeted | 24/30 | success=False | target_queries=2481
# before |          occlusion |   targeted | 24/30 | success=False | target_queries=2678
# before |            uniform |   targeted | 25/30 | success=False | target_queries=2481
# before |  surrogate_gradcam |   targeted | 25/30 | success=False | target_queries=2481
# before |          occlusion |   targeted | 25/30 | success=False | target_queries=2678
# before |            uniform |   targeted | 26/30 | success=False | target_queries=2481
# before |  surrogate_gradcam |   targeted | 26/30 | success=False | target_queries=2481
# before |          occlusion |   targeted | 26/30 | success=False | target_queries=2678
# before |            uniform |   targeted | 27/30 | success=False | target_queries=2481
# before |  surrogate_gradcam |   targeted | 27/30 | success=False | target_queries=2481
# before |          occlusion |   targeted | 27/30 | success=False | target_queries=2678
# before |            uniform |   targeted | 28/30 | success=False | target_queries=2481
# before |  surrogate_gradcam |   targeted | 28/30 | success=False | target_queries=2481
# before |          occlusion |   targeted | 28/30 | success=False | target_queries=2678
# before |            uniform |   targeted | 29/30 | success=False | target_queries=2481
# before |  surrogate_gradcam |   targeted | 29/30 | success=False | target_queries=2481
# before |          occlusion |   targeted | 29/30 | success=False | target_queries=2678
# before |            uniform |   targeted | 30/30 | success=False | target_queries=2481
# before |  surrogate_gradcam |   targeted | 30/30 | success=False | target_queries=2481
# before |          occlusion |   targeted | 30/30 | success=False | target_queries=2678
#  after |            uniform | untargeted | 01/30 | success=False | target_queries=2481
#  after |  surrogate_gradcam | untargeted | 01/30 | success=False | target_queries=2481
#  after |          occlusion | untargeted | 01/30 | success=False | target_queries=2678
#  after |            uniform | untargeted | 02/30 | success=False | target_queries=2481
#  after |  surrogate_gradcam | untargeted | 02/30 | success=False | target_queries=2481
#  after |          occlusion | untargeted | 02/30 | success=False | target_queries=2678
#  after |            uniform | untargeted | 03/30 | success=False | target_queries=2481
#  after |  surrogate_gradcam | untargeted | 03/30 | success=False | target_queries=2481
#  after |          occlusion | untargeted | 03/30 | success=False | target_queries=2678
#  after |            uniform | untargeted | 04/30 | success=False | target_queries=2481
#  after |  surrogate_gradcam | untargeted | 04/30 | success=False | target_queries=2481
#  after |          occlusion | untargeted | 04/30 | success=False | target_queries=2678
#  after |            uniform | untargeted | 05/30 | success=False | target_queries=2481
#  after |  surrogate_gradcam | untargeted | 05/30 | success=False | target_queries=2481
#  after |          occlusion | untargeted | 05/30 | success=False | target_queries=2678
#  after |            uniform | untargeted | 06/30 | success=False | target_queries=2481
#  after |  surrogate_gradcam | untargeted | 06/30 | success=False | target_queries=2481
#  after |          occlusion | untargeted | 06/30 | success=False | target_queries=2678
#  after |            uniform | untargeted | 07/30 | success=False | target_queries=2481
#  after |  surrogate_gradcam | untargeted | 07/30 | success=False | target_queries=2481
#  after |          occlusion | untargeted | 07/30 | success=False | target_queries=2678
#  after |            uniform | untargeted | 08/30 | success=False | target_queries=2481
#  after |  surrogate_gradcam | untargeted | 08/30 | success=False | target_queries=2481
#  after |          occlusion | untargeted | 08/30 | success=False | target_queries=2678
#  after |            uniform | untargeted | 09/30 | success=False | target_queries=2481
#  after |  surrogate_gradcam | untargeted | 09/30 | success=False | target_queries=2481
#  after |          occlusion | untargeted | 09/30 | success=False | target_queries=2678
#  after |            uniform | untargeted | 10/30 | success=False | target_queries=2481
#  after |  surrogate_gradcam | untargeted | 10/30 | success=False | target_queries=2481
#  after |          occlusion | untargeted | 10/30 | success=False | target_queries=2678
#  after |            uniform | untargeted | 11/30 | success=False | target_queries=2481
#  after |  surrogate_gradcam | untargeted | 11/30 | success=False | target_queries=2481
#  after |          occlusion | untargeted | 11/30 | success=False | target_queries=2678
#  after |            uniform | untargeted | 12/30 | success=False | target_queries=2481
#  after |  surrogate_gradcam | untargeted | 12/30 | success=False | target_queries=2481
#  after |          occlusion | untargeted | 12/30 | success=False | target_queries=2678
#  after |            uniform | untargeted | 13/30 | success=False | target_queries=2481
#  after |  surrogate_gradcam | untargeted | 13/30 | success=False | target_queries=2481
#  after |          occlusion | untargeted | 13/30 | success=False | target_queries=2678
#  after |            uniform | untargeted | 14/30 | success=False | target_queries=2481
#  after |  surrogate_gradcam | untargeted | 14/30 | success=False | target_queries=2481
#  after |          occlusion | untargeted | 14/30 | success=False | target_queries=2678
#  after |            uniform | untargeted | 15/30 | success=False | target_queries=2481
#  after |  surrogate_gradcam | untargeted | 15/30 | success=False | target_queries=2481
#  after |          occlusion | untargeted | 15/30 | success=False | target_queries=2678
#  after |            uniform | untargeted | 16/30 | success=False | target_queries=2481
#  after |  surrogate_gradcam | untargeted | 16/30 | success=False | target_queries=2481
#  after |          occlusion | untargeted | 16/30 | success=False | target_queries=2678
#  after |            uniform | untargeted | 17/30 | success=False | target_queries=2481
#  after |  surrogate_gradcam | untargeted | 17/30 | success=False | target_queries=2481
#  after |          occlusion | untargeted | 17/30 | success=False | target_queries=2678
#  after |            uniform | untargeted | 18/30 | success=False | target_queries=2481
#  after |  surrogate_gradcam | untargeted | 18/30 | success=False | target_queries=2481
#  after |          occlusion | untargeted | 18/30 | success=False | target_queries=2678
#  after |            uniform | untargeted | 19/30 | success=False | target_queries=2481
#  after |  surrogate_gradcam | untargeted | 19/30 | success=False | target_queries=2481
#  after |          occlusion | untargeted | 19/30 | success=False | target_queries=2678
#  after |            uniform | untargeted | 20/30 | success=False | target_queries=2481
#  after |  surrogate_gradcam | untargeted | 20/30 | success=False | target_queries=2481
#  after |          occlusion | untargeted | 20/30 | success=False | target_queries=2678
#  after |            uniform | untargeted | 21/30 | success=False | target_queries=2481
#  after |  surrogate_gradcam | untargeted | 21/30 | success=False | target_queries=2481
#  after |          occlusion | untargeted | 21/30 | success=False | target_queries=2678
#  after |            uniform | untargeted | 22/30 | success=False | target_queries=2481
#  after |  surrogate_gradcam | untargeted | 22/30 | success=False | target_queries=2481
#  after |          occlusion | untargeted | 22/30 | success=False | target_queries=2678
#  after |            uniform | untargeted | 23/30 | success=False | target_queries=2481
#  after |  surrogate_gradcam | untargeted | 23/30 | success=False | target_queries=2481
#  after |          occlusion | untargeted | 23/30 | success=False | target_queries=2678
#  after |            uniform | untargeted | 24/30 | success=False | target_queries=2481
#  after |  surrogate_gradcam | untargeted | 24/30 | success=False | target_queries=2481
#  after |          occlusion | untargeted | 24/30 | success=False | target_queries=2678
#  after |            uniform | untargeted | 25/30 | success=False | target_queries=2481
#  after |  surrogate_gradcam | untargeted | 25/30 | success=False | target_queries=2481
#  after |          occlusion | untargeted | 25/30 | success=False | target_queries=2678
#  after |            uniform | untargeted | 26/30 | success=False | target_queries=2481
#  after |  surrogate_gradcam | untargeted | 26/30 | success=False | target_queries=2481
#  after |          occlusion | untargeted | 26/30 | success=False | target_queries=2678
#  after |            uniform | untargeted | 27/30 | success=False | target_queries=2481
#  after |  surrogate_gradcam | untargeted | 27/30 | success=False | target_queries=2481
#  after |          occlusion | untargeted | 27/30 | success=False | target_queries=2678
#  after |            uniform | untargeted | 28/30 | success=False | target_queries=2481
#  after |  surrogate_gradcam | untargeted | 28/30 | success=False | target_queries=2481
#  after |          occlusion | untargeted | 28/30 | success=False | target_queries=2678
#  after |            uniform | untargeted | 29/30 | success=False | target_queries=2481
#  after |  surrogate_gradcam | untargeted | 29/30 | success=False | target_queries=2481
#  after |          occlusion | untargeted | 29/30 | success=False | target_queries=2678
#  after |            uniform | untargeted | 30/30 | success=False | target_queries=2481
#  after |  surrogate_gradcam | untargeted | 30/30 | success=False | target_queries=2481
#  after |          occlusion | untargeted | 30/30 | success=False | target_queries=2678
#  after |            uniform |   targeted | 01/30 | success=False | target_queries=2481
#  after |  surrogate_gradcam |   targeted | 01/30 | success=False | target_queries=2481
#  after |          occlusion |   targeted | 01/30 | success=False | target_queries=2678
#  after |            uniform |   targeted | 02/30 | success=False | target_queries=2481
#  after |  surrogate_gradcam |   targeted | 02/30 | success=False | target_queries=2481
#  after |          occlusion |   targeted | 02/30 | success=False | target_queries=2678
#  after |            uniform |   targeted | 03/30 | success=False | target_queries=2481
#  after |  surrogate_gradcam |   targeted | 03/30 | success=False | target_queries=2481
#  after |          occlusion |   targeted | 03/30 | success=False | target_queries=2678
#  after |            uniform |   targeted | 04/30 | success=False | target_queries=2481
#  after |  surrogate_gradcam |   targeted | 04/30 | success=False | target_queries=2481
#  after |          occlusion |   targeted | 04/30 | success=False | target_queries=2678
#  after |            uniform |   targeted | 05/30 | success=False | target_queries=2481
#  after |  surrogate_gradcam |   targeted | 05/30 | success=False | target_queries=2481
#  after |          occlusion |   targeted | 05/30 | success=False | target_queries=2678
#  after |            uniform |   targeted | 06/30 | success=False | target_queries=2481
#  after |  surrogate_gradcam |   targeted | 06/30 | success=False | target_queries=2481
#  after |          occlusion |   targeted | 06/30 | success=False | target_queries=2678
#  after |            uniform |   targeted | 07/30 | success=False | target_queries=2481
#  after |  surrogate_gradcam |   targeted | 07/30 | success=False | target_queries=2481
#  after |          occlusion |   targeted | 07/30 | success=False | target_queries=2678
#  after |            uniform |   targeted | 08/30 | success=False | target_queries=2481
#  after |  surrogate_gradcam |   targeted | 08/30 | success=False | target_queries=2481
#  after |          occlusion |   targeted | 08/30 | success=False | target_queries=2678
#  after |            uniform |   targeted | 09/30 | success=False | target_queries=2481
#  after |  surrogate_gradcam |   targeted | 09/30 | success=False | target_queries=2481
#  after |          occlusion |   targeted | 09/30 | success=False | target_queries=2678
#  after |            uniform |   targeted | 10/30 | success=False | target_queries=2481
#  after |  surrogate_gradcam |   targeted | 10/30 | success=False | target_queries=2481
#  after |          occlusion |   targeted | 10/30 | success=False | target_queries=2678
#  after |            uniform |   targeted | 11/30 | success=False | target_queries=2481
#  after |  surrogate_gradcam |   targeted | 11/30 | success=False | target_queries=2481
#  after |          occlusion |   targeted | 11/30 | success=False | target_queries=2678
#  after |            uniform |   targeted | 12/30 | success=False | target_queries=2481
#  after |  surrogate_gradcam |   targeted | 12/30 | success=False | target_queries=2481
#  after |          occlusion |   targeted | 12/30 | success=False | target_queries=2678
#  after |            uniform |   targeted | 13/30 | success=False | target_queries=2481
#  after |  surrogate_gradcam |   targeted | 13/30 | success=False | target_queries=2481
#  after |          occlusion |   targeted | 13/30 | success=False | target_queries=2678
#  after |            uniform |   targeted | 14/30 | success=False | target_queries=2481
#  after |  surrogate_gradcam |   targeted | 14/30 | success=False | target_queries=2481
#  after |          occlusion |   targeted | 14/30 | success=False | target_queries=2678
#  after |            uniform |   targeted | 15/30 | success=False | target_queries=2481
#  after |  surrogate_gradcam |   targeted | 15/30 | success=False | target_queries=2481
#  after |          occlusion |   targeted | 15/30 | success=False | target_queries=2678
#  after |            uniform |   targeted | 16/30 | success=False | target_queries=2481
#  after |  surrogate_gradcam |   targeted | 16/30 | success=False | target_queries=2481
#  after |          occlusion |   targeted | 16/30 | success=False | target_queries=2678
#  after |            uniform |   targeted | 17/30 | success=False | target_queries=2481
#  after |  surrogate_gradcam |   targeted | 17/30 | success=False | target_queries=2481
#  after |          occlusion |   targeted | 17/30 | success=False | target_queries=2678
#  after |            uniform |   targeted | 18/30 | success=False | target_queries=2481
#  after |  surrogate_gradcam |   targeted | 18/30 | success=False | target_queries=2481
#  after |          occlusion |   targeted | 18/30 | success=False | target_queries=2678
#  after |            uniform |   targeted | 19/30 | success=False | target_queries=2481
#  after |  surrogate_gradcam |   targeted | 19/30 | success=False | target_queries=2481
#  after |          occlusion |   targeted | 19/30 | success=False | target_queries=2678
#  after |            uniform |   targeted | 20/30 | success=False | target_queries=2481
#  after |  surrogate_gradcam |   targeted | 20/30 | success=False | target_queries=2481
#  after |          occlusion |   targeted | 20/30 | success=False | target_queries=2678
#  after |            uniform |   targeted | 21/30 | success=False | target_queries=2481
#  after |  surrogate_gradcam |   targeted | 21/30 | success=False | target_queries=2481
#  after |          occlusion |   targeted | 21/30 | success=False | target_queries=2678
#  after |            uniform |   targeted | 22/30 | success=False | target_queries=2481
#  after |  surrogate_gradcam |   targeted | 22/30 | success=False | target_queries=2481
#  after |          occlusion |   targeted | 22/30 | success=False | target_queries=2678
#  after |            uniform |   targeted | 23/30 | success=False | target_queries=2481
#  after |  surrogate_gradcam |   targeted | 23/30 | success=False | target_queries=2481
#  after |          occlusion |   targeted | 23/30 | success=False | target_queries=2678
#  after |            uniform |   targeted | 24/30 | success=False | target_queries=2481
#  after |  surrogate_gradcam |   targeted | 24/30 | success=False | target_queries=2481
#  after |          occlusion |   targeted | 24/30 | success=False | target_queries=2678
#  after |            uniform |   targeted | 25/30 | success=False | target_queries=2481
#  after |  surrogate_gradcam |   targeted | 25/30 | success=False | target_queries=2481
#  after |          occlusion |   targeted | 25/30 | success=False | target_queries=2678
#  after |            uniform |   targeted | 26/30 | success=False | target_queries=2481
#  after |  surrogate_gradcam |   targeted | 26/30 | success=False | target_queries=2481
#  after |          occlusion |   targeted | 26/30 | success=False | target_queries=2678
#  after |            uniform |   targeted | 27/30 | success=False | target_queries=2481
#  after |  surrogate_gradcam |   targeted | 27/30 | success=False | target_queries=2481
#  after |          occlusion |   targeted | 27/30 | success=False | target_queries=2678
#  after |            uniform |   targeted | 28/30 | success=False | target_queries=2481
#  after |  surrogate_gradcam |   targeted | 28/30 | success=False | target_queries=2481
#  after |          occlusion |   targeted | 28/30 | success=False | target_queries=2678
#  after |            uniform |   targeted | 29/30 | success=False | target_queries=2481
#  after |  surrogate_gradcam |   targeted | 29/30 | success=False | target_queries=2481
#  after |          occlusion |   targeted | 29/30 | success=False | target_queries=2678
#  after |            uniform |   targeted | 30/30 | success=False | target_queries=2481
#  after |  surrogate_gradcam |   targeted | 30/30 | success=False | target_queries=2481
#  after |          occlusion |   targeted | 30/30 | success=False | target_queries=2678
#               method        mode target_model surrogate_model  sample_index  \
# 0            uniform  untargeted       before            None             0
# 1  surrogate_gradcam  untargeted       before           after             0
# 2          occlusion  untargeted       before            None             0
# 3            uniform  untargeted       before            None             1
# 4  surrogate_gradcam  untargeted       before           after             1
#
#    dataset_index  true_class  target_class  clean_prediction  \
# 0              0           0           NaN                 0
# 1              0           0           NaN                 0
# 2              0           0           NaN                 0
# 3              1           0           NaN                 0
# 4              1           0           NaN                 0
#
#    adversarial_prediction  ...  post_attack_correct  de_evaluations  \
# 0                       0  ...                 True            2481
# 1                       0  ...                 True            2481
# 2                       0  ...                 True            2481
# 3                       0  ...                 True            2481
# 4                       0  ...                 True            2481
#
#    guidance_target_queries  surrogate_backward_passes  total_target_queries  \
# 0                        0                          0                  2481
# 1                        0                          1                  2481
# 2                      197                          0                  2678
# 3                        0                          0                  2481
# 4                        0                          1                  2481
#
#    generations    x    y          new_rgb changed_pixels
# 0           30  175  135   [255, 92, 216]              1
# 1           30  178  135  [255, 184, 237]              1
# 2           30  171  135  [116, 255, 255]              1
# 3           30   95   30       [62, 4, 9]              1
# 4           30   91   27       [0, 53, 0]              1
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Сводка и графики

# %%
guided_summary_df = (
    guided_results_df.groupby(['target_model', 'method', 'mode'], as_index=False)
    .agg(
        samples=('success', 'size'),
        success_rate=('success', 'mean'),
        robust_accuracy=('post_attack_correct', 'mean'),
        mean_de_evaluations=('de_evaluations', 'mean'),
        mean_guidance_queries=('guidance_target_queries', 'mean'),
        mean_total_target_queries=('total_target_queries', 'mean'),
        mean_surrogate_backward_passes=('surrogate_backward_passes', 'mean'),
    )
)
guided_summary_df.to_csv(OUTPUT_DIR / 'guided_onepixel_summary.csv', index=False)
display(guided_summary_df.style.format({
    'success_rate': '{:.2%}',
    'robust_accuracy': '{:.2%}',
    'mean_de_evaluations': '{:.1f}',
    'mean_guidance_queries': '{:.1f}',
    'mean_total_target_queries': '{:.1f}',
    'mean_surrogate_backward_passes': '{:.1f}',
}))

configuration = {
    'seed': SEED,
    'samples': MAX_ATTACK_SAMPLES,
    'methods': list(METHODS),
    'modes': list(MODES),
    'target_models': list(TARGET_MODEL_NAMES),
    'surrogate_for_target': SURROGATE_FOR_TARGET,
    'population_size': POPULATION_SIZE,
    'generations': GENERATIONS,
    'differential_weight': DIFFERENTIAL_WEIGHT,
    'guidance_strength': GUIDANCE_STRENGTH,
    'occlusion_patch_size': OCCLUSION_PATCH_SIZE,
    'predict_batch_size': PREDICT_BATCH_SIZE,
}
with (OUTPUT_DIR / 'guided_configuration.json').open('w', encoding='utf-8') as file:
    json.dump(configuration, file, ensure_ascii=False, indent=2)

fig, axes = plt.subplots(len(TARGET_MODEL_NAMES), 3, figsize=(17, 9), squeeze=False)
x = np.arange(len(METHODS))
width = 0.36
for row, target_model_name in enumerate(TARGET_MODEL_NAMES):
    target_rows = guided_summary_df[guided_summary_df['target_model'] == target_model_name]
    for mode_index, mode in enumerate(MODES):
        ordered = target_rows[target_rows['mode'] == mode].set_index('method').loc[list(METHODS)]
        positions = x + (-width / 2 if mode_index == 0 else width / 2)
        axes[row, 0].bar(positions, ordered['success_rate'] * 100, width=width, label=mode)
        axes[row, 1].bar(positions, ordered['robust_accuracy'] * 100, width=width, label=mode)
        axes[row, 2].bar(positions, ordered['mean_total_target_queries'], width=width, label=mode)
    axes[row, 0].set_title(f'{target_model_name}: attack success rate')
    axes[row, 0].set_ylabel('%')
    axes[row, 0].set_ylim(0, 100)
    axes[row, 1].set_title(f'{target_model_name}: robust accuracy')
    axes[row, 1].set_ylabel('%')
    axes[row, 1].set_ylim(0, 100)
    axes[row, 2].set_title(f'{target_model_name}: mean target-model queries')
    for axis in axes[row]:
        axis.set_xticks(x, ['Uniform DE', 'Surrogate\nGrad-CAM', 'Occlusion'])
        axis.grid(axis='y', alpha=0.3)
        axis.legend()
fig.tight_layout()
fig.savefig(OUTPUT_DIR / 'guided_onepixel_comparison.png', dpi=160, bbox_inches='tight')
plt.show()
# Out:
# <style type="text/css">
# </style>
# <table id="T_2e8e1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2e8e1_level0_col0" class="col_heading level0 col0" >target_model</th>
#       <th id="T_2e8e1_level0_col1" class="col_heading level0 col1" >method</th>
#       <th id="T_2e8e1_level0_col2" class="col_heading level0 col2" >mode</th>
#       <th id="T_2e8e1_level0_col3" class="col_heading level0 col3" >samples</th>
#       <th id="T_2e8e1_level0_col4" class="col_heading level0 col4" >success_rate</th>
#       <th id="T_2e8e1_level0_col5" class="col_heading level0 col5" >robust_accuracy</th>
#       <th id="T_2e8e1_level0_col6" class="col_heading level0 col6" >mean_de_evaluations</th>
#       <th id="T_2e8e1_level0_col7" class="col_heading level0 col7" >mean_guidance_queries</th>
#       <th id="T_2e8e1_level0_col8" class="col_heading level0 col8" >mean_total_target_queries</th>
#       <th id="T_2e8e1_level0_col9" class="col_heading level0 col9" >mean_surrogate_backward_passes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2e8e1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2e8e1_row0_col0" class="data row0 col0" >after</td>
#       <td id="T_2e8e1_row0_col1" class="data row0 col1" >occlusion</td>
#       <td id="T_2e8e1_row0_col2" class="data row0 col2" >targeted</td>
#       <td id="T_2e8e1_row0_col3" class="data row0 col3" >30</td>
#       <td id="T_2e8e1_row0_col4" class="data row0 col4" >0.00%</td>
#       <td id="T_2e8e1_row0_col5" class="data row0 col5" >100.00%</td>
#       <td id="T_2e8e1_row0_col6" class="data row0 col6" >2481.0</td>
#       <td id="T_2e8e1_row0_col7" class="data row0 col7" >197.0</td>
#       <td id="T_2e8e1_row0_col8" class="data row0 col8" >2678.0</td>
#       <td id="T_2e8e1_row0_col9" class="data row0 col9" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_2e8e1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2e8e1_row1_col0" class="data row1 col0" >after</td>
#       <td id="T_2e8e1_row1_col1" class="data row1 col1" >occlusion</td>
#       <td id="T_2e8e1_row1_col2" class="data row1 col2" >untargeted</td>
#       <td id="T_2e8e1_row1_col3" class="data row1 col3" >30</td>
#       <td id="T_2e8e1_row1_col4" class="data row1 col4" >0.00%</td>
#       <td id="T_2e8e1_row1_col5" class="data row1 col5" >100.00%</td>
#       <td id="T_2e8e1_row1_col6" class="data row1 col6" >2481.0</td>
#       <td id="T_2e8e1_row1_col7" class="data row1 col7" >197.0</td>
#       <td id="T_2e8e1_row1_col8" class="data row1 col8" >2678.0</td>
#       <td id="T_2e8e1_row1_col9" class="data row1 col9" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_2e8e1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2e8e1_row2_col0" class="data row2 col0" >after</td>
#       <td id="T_2e8e1_row2_col1" class="data row2 col1" >surrogate_gradcam</td>
#       <td id="T_2e8e1_row2_col2" class="data row2 col2" >targeted</td>
#       <td id="T_2e8e1_row2_col3" class="data row2 col3" >30</td>
#       <td id="T_2e8e1_row2_col4" class="data row2 col4" >0.00%</td>
#       <td id="T_2e8e1_row2_col5" class="data row2 col5" >100.00%</td>
#       <td id="T_2e8e1_row2_col6" class="data row2 col6" >2481.0</td>
#       <td id="T_2e8e1_row2_col7" class="data row2 col7" >0.0</td>
#       <td id="T_2e8e1_row2_col8" class="data row2 col8" >2481.0</td>
#       <td id="T_2e8e1_row2_col9" class="data row2 col9" >2.0</td>
#     </tr>
#     <tr>
#       <th id="T_2e8e1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2e8e1_row3_col0" class="data row3 col0" >after</td>
#       <td id="T_2e8e1_row3_col1" class="data row3 col1" >surrogate_gradcam</td>
#       <td id="T_2e8e1_row3_col2" class="data row3 col2" >untargeted</td>
#       <td id="T_2e8e1_row3_col3" class="data row3 col3" >30</td>
#       <td id="T_2e8e1_row3_col4" class="data row3 col4" >0.00%</td>
#       <td id="T_2e8e1_row3_col5" class="data row3 col5" >100.00%</td>
#       <td id="T_2e8e1_row3_col6" class="data row3 col6" >2481.0</td>
#       <td id="T_2e8e1_row3_col7" class="data row3 col7" >0.0</td>
#       <td id="T_2e8e1_row3_col8" class="data row3 col8" >2481.0</td>
#       <td id="T_2e8e1_row3_col9" class="data row3 col9" >1.0</td>
#     </tr>
#     <tr>
#       <th id="T_2e8e1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2e8e1_row4_col0" class="data row4 col0" >after</td>
#       <td id="T_2e8e1_row4_col1" class="data row4 col1" >uniform</td>
#       <td id="T_2e8e1_row4_col2" class="data row4 col2" >targeted</td>
#       <td id="T_2e8e1_row4_col3" class="data row4 col3" >30</td>
#       <td id="T_2e8e1_row4_col4" class="data row4 col4" >0.00%</td>
#       <td id="T_2e8e1_row4_col5" class="data row4 col5" >100.00%</td>
#       <td id="T_2e8e1_row4_col6" class="data row4 col6" >2481.0</td>
#       <td id="T_2e8e1_row4_col7" class="data row4 col7" >0.0</td>
#       <td id="T_2e8e1_row4_col8" class="data row4 col8" >2481.0</td>
#       <td id="T_2e8e1_row4_col9" class="data row4 col9" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_2e8e1_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2e8e1_row5_col0" class="data row5 col0" >after</td>
#       <td id="T_2e8e1_row5_col1" class="data row5 col1" >uniform</td>
#       <td id="T_2e8e1_row5_col2" class="data row5 col2" >untargeted</td>
#       <td id="T_2e8e1_row5_col3" class="data row5 col3" >30</td>
#       <td id="T_2e8e1_row5_col4" class="data row5 col4" >0.00%</td>
#       <td id="T_2e8e1_row5_col5" class="data row5 col5" >100.00%</td>
#       <td id="T_2e8e1_row5_col6" class="data row5 col6" >2481.0</td>
#       <td id="T_2e8e1_row5_col7" class="data row5 col7" >0.0</td>
#       <td id="T_2e8e1_row5_col8" class="data row5 col8" >2481.0</td>
#       <td id="T_2e8e1_row5_col9" class="data row5 col9" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_2e8e1_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2e8e1_row6_col0" class="data row6 col0" >before</td>
#       <td id="T_2e8e1_row6_col1" class="data row6 col1" >occlusion</td>
#       <td id="T_2e8e1_row6_col2" class="data row6 col2" >targeted</td>
#       <td id="T_2e8e1_row6_col3" class="data row6 col3" >30</td>
#       <td id="T_2e8e1_row6_col4" class="data row6 col4" >3.33%</td>
#       <td id="T_2e8e1_row6_col5" class="data row6 col5" >96.67%</td>
#       <td id="T_2e8e1_row6_col6" class="data row6 col6" >2481.0</td>
#       <td id="T_2e8e1_row6_col7" class="data row6 col7" >197.0</td>
#       <td id="T_2e8e1_row6_col8" class="data row6 col8" >2678.0</td>
#       <td id="T_2e8e1_row6_col9" class="data row6 col9" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_2e8e1_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2e8e1_row7_col0" class="data row7 col0" >before</td>
#       <td id="T_2e8e1_row7_col1" class="data row7 col1" >occlusion</td>
#       <td id="T_2e8e1_row7_col2" class="data row7 col2" >untargeted</td>
#       <td id="T_2e8e1_row7_col3" class="data row7 col3" >30</td>
#       <td id="T_2e8e1_row7_col4" class="data row7 col4" >6.67%</td>
#       <td id="T_2e8e1_row7_col5" class="data row7 col5" >93.33%</td>
#       <td id="T_2e8e1_row7_col6" class="data row7 col6" >2481.0</td>
#       <td id="T_2e8e1_row7_col7" class="data row7 col7" >197.0</td>
#       <td id="T_2e8e1_row7_col8" class="data row7 col8" >2678.0</td>
#       <td id="T_2e8e1_row7_col9" class="data row7 col9" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_2e8e1_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_2e8e1_row8_col0" class="data row8 col0" >before</td>
#       <td id="T_2e8e1_row8_col1" class="data row8 col1" >surrogate_gradcam</td>
#       <td id="T_2e8e1_row8_col2" class="data row8 col2" >targeted</td>
#       <td id="T_2e8e1_row8_col3" class="data row8 col3" >30</td>
#       <td id="T_2e8e1_row8_col4" class="data row8 col4" >0.00%</td>
#       <td id="T_2e8e1_row8_col5" class="data row8 col5" >100.00%</td>
#       <td id="T_2e8e1_row8_col6" class="data row8 col6" >2481.0</td>
#       <td id="T_2e8e1_row8_col7" class="data row8 col7" >0.0</td>
#       <td id="T_2e8e1_row8_col8" class="data row8 col8" >2481.0</td

# %% [markdown]
# ## Карты guidance и результаты атак

# %%
def signed_perturbation(delta, scale):
    return np.clip(0.5 + scale * delta, 0.0, 1.0)


def zoom_pixel(image, x, y, radius=6, size=160):
    top, bottom = max(0, y - radius), min(image.shape[0], y + radius + 1)
    left, right = max(0, x - radius), min(image.shape[1], x + radius + 1)
    crop = Image.fromarray(image[top:bottom, left:right])
    return np.asarray(crop.resize((size, size), Image.Resampling.NEAREST))


if visual_examples:
    fig, axes = plt.subplots(len(visual_examples), 6, figsize=(19, 3.1 * len(visual_examples)), squeeze=False)
    for row, example in enumerate(visual_examples):
        original = example['original']
        adversarial = example['adversarial']
        guidance = example['guidance']
        delta = adversarial.astype(np.float32) / 255.0 - original.astype(np.float32) / 255.0
        perturbation_x1 = signed_perturbation(delta, 1.0)
        perturbation_x20 = signed_perturbation(delta, 20.0)
        zoom = zoom_pixel(adversarial, example['x'], example['y'])
        example_dir = EXAMPLES_DIR / (
            f"{example['target_model']}_{example['method']}_{example['mode']}_sample_{example['sample_index']:02d}"
        )
        example_dir.mkdir(parents=True, exist_ok=True)
        Image.fromarray(original).save(example_dir / 'original.png')
        Image.fromarray(adversarial).save(example_dir / 'adversarial.png')
        plt.imsave(example_dir / 'guidance_map.png', guidance, cmap='inferno')
        Image.fromarray((perturbation_x1 * 255).astype(np.uint8)).save(example_dir / 'perturbation_x1.png')
        Image.fromarray((perturbation_x20 * 255).astype(np.uint8)).save(example_dir / 'perturbation_x20.png')
        Image.fromarray(zoom).save(example_dir / 'pixel_zoom.png')
        np.save(example_dir / 'guidance_map.npy', guidance)
        np.save(example_dir / 'perturbation_raw.npy', delta)
        images = [original, guidance, adversarial, perturbation_x1, perturbation_x20, zoom]
        titles = [
            'Original', 'Guidance map',
            f"Adversarial: {example['adversarial_prediction']} / success={example['success']}",
            'Perturbation x1', 'Perturbation x20', f"Pixel ({example['x']}, {example['y']})",
        ]
        for column, (axis, shown, title) in enumerate(zip(axes[row], images, titles)):
            axis.imshow(shown, cmap='inferno' if column == 1 else None)
            axis.set_title(
                f"target={example['target_model']} / {example['method']} / {example['mode']}\n{title}",
                fontsize=8,
            )
            axis.axis('off')
    fig.tight_layout()
    fig.savefig(OUTPUT_DIR / 'guided_examples.png', dpi=160, bbox_inches='tight')
    plt.show()

# %% [markdown]
# ## Финальные проверки

# %%
fingerprints_after_guided = {name: model_fingerprint(net) for name, net in models_by_name.items()}
assert fingerprints_after_guided == fingerprints_before, 'Атака изменила веса моделей'
assert len(guided_results_df) == len(TARGET_MODEL_NAMES) * len(METHODS) * len(MODES) * MAX_ATTACK_SAMPLES
assert guided_results_df['changed_pixels'].le(1).all()
assert (guided_results_df['clean_prediction'] == guided_results_df['true_class']).all()
assert (guided_results_df['total_target_queries'] >= guided_results_df['de_evaluations']).all()
assert (
    guided_results_df.loc[guided_results_df['method'] != 'occlusion', 'guidance_target_queries'] == 0
).all()
for required in (
    OUTPUT_DIR / 'guided_onepixel_results.csv',
    OUTPUT_DIR / 'guided_onepixel_summary.csv',
    OUTPUT_DIR / 'guided_configuration.json',
    OUTPUT_DIR / 'guided_onepixel_comparison.png',
):
    assert required.is_file(), required
print('Все проверки пройдены. Saved files:')
for path in sorted(OUTPUT_DIR.rglob('*')):
    if path.is_file():
        print(' ', path)
# Out:
# Все проверки пройдены. Saved files:
#   /kaggle/working/imagewoof_guided_onepixel/examples/after_occlusion_targeted_sample_00/adversarial.png
#   /kaggle/working/imagewoof_guided_onepixel/examples/after_occlusion_targeted_sample_00/guidance_map.npy
#   /kaggle/working/imagewoof_guided_onepixel/examples/after_occlusion_targeted_sample_00/guidance_map.png
#   /kaggle/working/imagewoof_guided_onepixel/examples/after_occlusion_targeted_sample_00/original.png
#   /kaggle/working/imagewoof_guided_onepixel/examples/after_occlusion_targeted_sample_00/perturbation_raw.npy
#   /kaggle/working/imagewoof_guided_onepixel/examples/after_occlusion_targeted_sample_00/perturbation_x1.png
#   /kaggle/working/imagewoof_guided_onepixel/examples/after_occlusion_targeted_sample_00/perturbation_x20.png
#   /kaggle/working/imagewoof_guided_onepixel/examples/after_occlusion_targeted_sample_00/pixel_zoom.png
#   /kaggle/working/imagewoof_guided_onepixel/examples/after_occlusion_untargeted_sample_00/adversarial.png
#   /kaggle/working/imagewoof_guided_onepixel/examples/after_occlusion_untargeted_sample_00/guidance_map.npy
#   /kaggle/working/imagewoof_guided_onepixel/examples/after_occlusion_untargeted_sample_00/guidance_map.png
#   /kaggle/working/imagewoof_guided_onepixel/examples/after_occlusion_untargeted_sample_00/original.png
#   /kaggle/working/imagewoof_guided_onepixel/examples/after_occlusion_untargeted_sample_00/perturbation_raw.npy
#   /kaggle/working/imagewoof_guided_onepixel/examples/after_occlusion_untargeted_sample_00/perturbation_x1.png
#   /kaggle/working/imagewoof_guided_onepixel/examples/after_occlusion_untargeted_sample_00/perturbation_x20.png
#   /kaggle/working/imagewoof_guided_onepixel/examples/after_occlusion_untargeted_sample_00/pixel_zoom.png
#   /kaggle/working/imagewoof_guided_onepixel/examples/after_surrogate_gradcam_targeted_sample_00/adversarial.png
#   /kaggle/working/imagewoof_guided_onepixel/examples/after_surrogate_gradcam_targeted_sample_00/guidance_map.npy
#   /kaggle/working/imagewoof_guided_onepixel/examples/after_surrogate_gradcam_targeted_sample_00/guidance_map.png
#   /kaggle/working/imagewoof_guided_onepixel/examples/after_surrogate_gradcam_targeted_sample_00/original.png
#   /kaggle/working/imagewoof_guided_onepixel/examples/after_surrogate_gradcam_targeted_sample_00/perturbation_raw.npy
#   /kaggle/working/imagewoof_guided_onepixel/examples/after_surrogate_gradcam_targeted_sample_00/perturbation_x1.png
#   /kaggle/working/imagewoof_guided_onepixel/examples/after_surrogate_gradcam_targeted_sample_00/perturbation_x20.png
#   /kaggle/working/imagewoof_guided_onepixel/examples/after_surrogate_gradcam_targeted_sample_00/pixel_zoom.png
#   /kaggle/working/imagewoof_guided_onepixel/examples/after_surrogate_gradcam_untargeted_sample_00/adversarial.png
#   /kaggle/working/imagewoof_guided_onepixel/examples/after_surrogate_gradcam_untargeted_sample_00/guidance_map.npy
#   /kaggle/working/imagewoof_guided_onepixel/examples/after_surrogate_gradcam_untargeted_sample_00/guidance_map.png
#   /kaggle/working/imagewoof_guided_onepixel/examples/after_surrogate_gradcam_untargeted_sample_00/original.png
#   /kaggle/working/imagewoof_guided_onepixel/examples/after_surrogate_gradcam_untargeted_sample_00/perturbation_raw.npy
#   /kaggle/working/imagewoof_guided_onepixel/examples/after_surrogate_gradcam_untargeted_sample_00/perturbation_x1.png
#   /kaggle/working/imagewoof_guided_onepixel/examples/after_surrogate_gradcam_untargeted_sample_00/perturbation_x20.png
#   /kaggle/working/imagewoof_guided_onepixel/examples/after_surrogate_gradcam_untargeted_sample_00/pixel_zoom.png
#   /kaggle/working/imagewoof_guided_onepixel/examples/before_occlusion_targeted_sample_00/adversarial.png
#   /kaggle/working/imagewoof_guided_onepixel/examples/before_occlusion_targeted_sample_00/guidance_map.npy
#   /kaggle/working/imagewoof_guided_onepixel/examples/before_occlusion_targeted_sample_00/guidance_map.png
#   /kaggle/working/imagewoof_guided_onepixel/examples/before_occlusion_targeted_sample_00/original.png
#   /kaggle/working/imagewoof_guided_onepixel/examples/before_occlusion_targeted_sample_00/perturbation_raw.npy
#   /kaggle/working/imagewoof_guided_onepixel/examples/before_occlusion_targeted_sample_00/perturbation_x1.png
#   /kaggle/working/imagewoof_guided_onepixel/examples/before_occlusion_targeted_sample_00/perturbation_x20.png
#   /kaggle/working/imagewoof_guided_onepixel/examples/before_occlusion_targeted_sample_00/pixel_zoom.png
#   /kaggle/working/imagewoof_guided_onepixel/examples/before_occlusion_untargeted_sample_00/adversarial.png
#   /kaggle/working/imagewoof_guided_onepixel/examples/before_occlusion_untargeted_sample_00/guidance_map.npy
#   /kaggle/working/imagewoof_guided_onepixel/examples/before_occlusion_untargeted_sample_00/guidance_map.png
#   /kaggle/working/imagewoof_guided_onepixel/examples/before_occlusion_untargeted_sample_00/original.png
#   /kaggle/working/imagewoof_guided_onepixel/examples/before_occlusion_untargeted_sample_00/perturbation_raw.npy
#   /kaggle/working/imagewoof_guided_onepixel/examples/before_occlusion_untargeted_sample_00/perturbation_x1.png
#   /kaggle/working/imagewoof_guided_onepixel/examples/before_occlusion_untargeted_sample_00/perturbation_x20.png
#   /kaggle/working/imagewoof_guided_onepixel/examples/before_occlusion_untargeted_sample_00/pixel_zoom.png
#   /kaggle/working/imagewoof_guided_onepixel/examples/before_surrogate_gradcam_targeted_sample_00/adversarial.png
#   /kaggle/working/imagewoof_guided_onepixel/examples/before_surrogate_gradcam_targeted_sample_00/guidance_map.npy
#   /kaggle/working/imagewoof_guided_onepixel/examples/before_surrogate_gradcam_targeted_sample_00/guidance_map.png
#   /kaggle/working/imagewoof_guided_onepixel/examples/before_surrogate_gradcam_targeted_sample_00/original.png
#   /kaggle/working/imagewoof_guided_onepixel/examples/before_surrogate_gradcam_targeted_sample_00/perturbation_raw.npy
#   /kaggle/working/imagewoof_guided_onepixel/examples/before_surrogate_gradcam_targeted_sample_00/perturbation_x1.png
#   /kaggle/working/imagewoof_guided_onepixel/examples/before_surrogate_gradcam_targeted_sample_00/perturbation_x20.png
#   /kaggle/working/imagewoof_guided_onepixel/examples/before_surrogate_gradcam_targeted_sample_00/pixel_zoom.png
#   /kaggle/working/imagewoof_guided_onepixel/examples/before_surrogate_gradcam_untargeted_sample_00/adversarial.png
#   /kaggle/working/imagewoof_guided_onepixel/examples/before_surrogate_gradcam_untargeted_sample_00/guidance_map.npy
#   /kaggle/working/imagewoof_guided_onepixel/examples/before_surrogate_gradcam_untargeted_sample_00/guidance_map.png
#   /kaggle/working/imagewoof_guided_onepixel/examples/before_surrogate_gradcam_untargeted_sample_00/original.png
#   /kaggle/working/imagewoof_guided_onepixel/examples/before_surrogate_gradcam_untargeted_sample_00/perturbation_raw.npy
#   /kaggle/working/imagewoof_guided_onepixel/examples/before_surrogate_gradcam_untargeted_sample_00/perturbation_x1.png
#   /kaggle/working/imagewoof_guided_onepixel/examples/before_surrogate_gradcam_untargeted_sample_00/perturbation_x20.png
#   /kaggle/working/imagewoof_guided_onepixel/examples/before_surrogate_gradcam_untargeted_sample_00/pixel_zoom.png
#   /kaggle/working/imagewoof_guided_onepixel/guided_configuration.json
#   /kaggle/working/imagewoof_guided_onepixel/guided_examples.png
#   /kaggle/working/imagewoof_guided_onepixel/guided_onepixel_comparison.png
#   /kaggle/working/imagewoof_guided_onepixel/guided_onepixel_results.csv
#   /kaggle/working/imagewoof_guided_onepixel/guided_onepixel_summary.csv
